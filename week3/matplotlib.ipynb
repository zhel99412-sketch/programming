# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.axis([0,5,0,20])
# Out:
# (np.float64(0.0), np.float64(5.0), np.float64(0.0), np.float64(20.0))

# %%
t = np.arange(0,2.5,1)
t
# Out:
# array([0., 1., 2.])

# %%
plt.plot([1,2,3,5,2,7,3,6],linewidth=2.0)

# %%
plt.plot([1,2,3,5,2,7,3,6],linewidth=5.0)

# %%
t = np.arange(0, 5, 0.1)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)

plt.subplot(211)
plt.plot(t, y1, 'b-.')
plt.subplot(212)
plt.plot(t, y2, 'r--')

# %%
t = np.arange(0, 1, 0.05)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)

plt.subplot(121)
plt.plot(t, y1, 'b-.')
plt.subplot(122)
plt.plot(t, y2, 'r--')

# %%
plt.axis([0,5,0,20])
plt.title('My First plot', fontsize=20, fontname='Times New Roman')
plt.xlabel('Counting', color='gray')
plt.ylabel('Square values', color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My First plot', fontsize=20, fontname='Times New Roman')
plt.xlabel('Counting', color='gray')
plt.ylabel('Square values', color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.grid(True)

# %%
plt.axis([0,5,0,20])
plt.title('My First plot', fontsize=20, fontname='Times New Roman')
plt.xlabel('Counting', color='gray')
plt.ylabel('Square values', color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4], [1,4,9,16], 'ro', label='First Series')
plt.grid(True)
plt.legend(['First Series'])
plt.savefig('my_chart.png')

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

months = mdates.MonthLocator()                # 主刻度：按月
days = mdates.DayLocator()                    # 次刻度：按日
timeFmt = mdates.DateFormatter('%Y-%m')       # 日期格式：年-月

events = [
    datetime.date(2017,1,23),
    datetime.date(2017,1,21),
    datetime.date(2017,2,3),
    datetime.date(2017,2,24),
    datetime.date(2017,3,15),
    datetime.date(2017,3,24),
    datetime.date(2017,4,8),
    datetime.date(2017,4,24)
]

readings = [12,22,25,20,18,15,17,14]

fig, ax = plt.subplots()
plt.plot(events, readings)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.01)
y = np.sin(3*x)/x
plt.plot(x, y)

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.01)
y = np.sin(3*x)/x
plt.plot(x, y, color='r', linestyle='--', linewidth=5)

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.01)
y1 = np.sin(3*x)/x
y2 = np.sin(x)/x
plt.plot(x, y1)
plt.plot(x, y2, color='r', linestyle='--', linewidth=5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'series1': [1, 3, 4, 3, 5],
    'series2': [2, 4, 5, 2, 4],
    'series3': [3, 2, 3, 1, 3]
}

df = pd.DataFrame(data)
x = np.arange(5)
plt.axis([0, 5, 0, 7])
plt.plot(x, df)
plt.legend(data, loc=2)

# %%
import matplotlib.pyplot as plt
import numpy as np

pop = np.random.randint(0, 100, 100)
pop
# Out:
# array([99,  9, 45, 59, 61, 38, 59, 45, 75, 75, 54, 11, 61, 97, 42, 94, 68,
#        77, 37, 64, 38, 95, 88, 14, 58,  3, 28, 74, 77, 72, 24, 42,  6, 96,
#        92, 62, 30, 51, 42, 96, 69,  5, 25, 64, 52, 28, 16,  5,  3, 56, 95,
#         9, 61, 62, 74, 91, 45, 75, 62,  5, 38, 89, 15,  8, 86, 69, 37, 50,
#        85, 44, 27, 56, 31, 65, 59, 88,  3,  0, 41, 82, 24, 54, 23,  8, 13,
#         3, 10, 61, 39, 48, 12, 76, 21, 43, 32, 83,  6,  1, 61, 81])

# %%
plt.hist(pop, bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Random Integers')
plt.xlabel('Value Range')
plt.ylabel('Frequency')
plt.show()

# %%
index = np.arange(5)
values1 = [5, 7, 3, 4, 6]
plt.bar(index, values1)
plt.xticks(index + 0.4, ['A', 'B', 'C', 'D', 'E'])
# Out:
# ([<matplotlib.axis.XTick at 0x10da56b30>,
# ...
#  [Text(0.4, 0, 'A'),
#   Text(1.4, 0, 'B'),
#   Text(2.4, 0, 'C'),
#   Text(3.4, 0, 'D'),
#   Text(4.4, 0, 'E')])

# %%
index = np.arange(5)
values1 = [5, 7, 3, 4, 6]
std1 = [0.8, 1.0, 0.4, 0.9, 1.3]

plt.title('My Bar Chart')
plt.bar(
    index, values1,
    yerr=std1,
    error_kw={'ecolor': '0.1', 'capsize': 6},
    alpha=0.7,
    label='First'
)

plt.xticks(index + 0.4, ['A', 'B', 'C', 'D', 'E'])
plt.legend(loc=2)

# %%
labels = ['Nokia', 'Samsung', 'Huawei', 'Apple', 'Motorola']
values = [10, 20, 34, 56, 45]
colors = ['yellow', 'red', 'gray', 'orange', 'green']
explode = [0, 0.3, 0, 0, 0]

plt.title('A pie chart')
plt.pie(
    values,
    labels=labels,
    colors=colors,
    explode=explode,
    shadow=True,
    autopct='%1.1f%%',
    startangle=180
)
plt.axis('equal')
# Out:
# (np.float64(-1.2527625138639233),
#  np.float64(1.1072724243973833),
#  np.float64(-1.2224884774624112),
#  np.float64(1.1058322284727542))

# %%
import pandas as pd

data = {
    'series1': [1, 4, 4, 3, 5],
    'series2': [2, 4, 5, 2, 4],
    'series3': [3, 2, 3, 1, 3]
}

df = pd.DataFrame(data)
df['series1'].plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='series1'>
